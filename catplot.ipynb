# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

data = sns.load_dataset("tips")
#print(data)
sns.catplot(data = data ,  x = "day" ,  hue = "sex" , palette = "bright" ,  kind = "count")
plt.show()
